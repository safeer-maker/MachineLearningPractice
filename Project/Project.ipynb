# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Sample_of_Dataset.xlsx")

# %%
data
# Out:
#       StoreName   StoreCode                Date  DefaultTraffic  TrafficIN  \
# 0   new store 1  s003333356 2022-09-30 05:00:12               0          0
# 1         hpout        S011 2022-01-01 05:00:12             864        793
# 2         hpout        S011 2022-01-02 05:00:12             819        782
# 3         hpout        S011 2022-01-03 05:00:12             644        618
# 4         hpout        S011 2022-01-04 05:00:12             634        603
# ..          ...         ...                 ...             ...        ...
# 65       LBlock        s013 2022-03-06 05:00:12             263        260
# 66       LBlock        s013 2022-03-07 05:00:12             280        276
# 67       LBlock        s013 2022-03-08 05:00:12             254        233
# 68       LBlock        s013 2022-03-09 05:00:12             288        274
# 69       LBlock        s013 2022-03-10 05:00:12             319        347
#
# ...

# %%
data.describe()
# Out:
#        DefaultTraffic   TrafficIN   TrafficOUT       Units           Sale  \
# count       70.000000   70.000000    70.000000   70.000000      70.000000
# mean       611.528571  584.042857   611.528571   79.485714  231231.189429
# std        249.944152  231.937613   249.944152   35.783059   74200.250615
# min          0.000000    0.000000     0.000000    0.000000       0.000000
# 25%        320.750000  320.750000   320.750000   49.250000  170485.255000
# 50%        696.500000  671.500000   696.500000   83.500000  228331.105000
# 75%        805.250000  769.500000   805.250000  108.500000  289530.252500
# max       1037.000000  904.000000  1037.000000  144.000000  382470.410000
#
#        Transactions  Conversion        IPT          ATV          ASP  \
# count     70.000000   70.000000  70.000000    70.000000    70.000000
# mean      57.485714    0.094872   1.342034  4278.695139  3196.363582
# std       23.546281    0.020444   0.236811  1273.156264  1077.700470
# ...
