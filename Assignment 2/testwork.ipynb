# %%
import numpy as np
import pandas as pd

from typing import List, Dict
from anytree import NodeMixin, RenderTree
from anytree.search import find_by_attr, findall_by_attr
from math import log2

# %%
data  = pd.read_csv("data.csv")
data
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
class DecTreeNode(NodeMixin):
    def __init__(self, name: str, attribute: str, parent: DecTreeNode = None):
        super(DecTreeNode, self).__init__()
        self.name = name
        self.attribute = attribute
        self.parent = parent
        self.attr_value = "{0}={1}".format(attribute, name)

# %%
class DecTree():
    
    def __init__(self, data: pd.DataFrame, target_attribute: str):
        self.data = data
        self.target_attr = target_attribute
        self.target_attr_vals = data[target_attribute].unique()
        self.root_node = None
        
    def pmf_target(self, df: pd.DataFrame) -> Dict[str, float]:
        # Add your code
        pmf = dict()
        #print (df['play'])
        #arr , value = np[self.target_attr].unique(df, return_counts = True)
        arr , value = np.unique(df, return_counts = True)
        prob = np.array(value)/sum(value)
        pmf = dict (zip(arr,prob)) 
        return pmf
    
    def entropy(self, pmf: Dict[str, float]) -> float:
        # Add your code
        # taking the key values from dictionaty and converting it to numpy array
        perc = np.array(list(pmf.values()))
        perc[perc == 0] = 1
        #print ("value in Entropy = ", perc)
        #taking logs of all array using numpy.log2() method
        log = np.log2(perc)
        #individual intropy of all the dictionay values are calculated using numpy
        entr = perc * log
        entr[entr == np.nan] = 0
        #print ("entropy list = ", entr)
        #inverting the -ve values and summing them on return call
        return -entr.sum()

    def cal_entropy_df(self, df: pd.DataFrame) -> float:
        # Add your code
        # the data frame will be of two columns only. so that the entropy of an 
        # attribute agains its predecting attribute will be calculated properly
        # column_0 ==> predective attribute ;;;; column_1 = given attribute
        columns = df.columns
        
        # seperate the unique values and there count in both columns of dataframe
        uniq_wor_0, uniq_count_0  = np.unique(df[columns[0]], return_counts = True)
        uniq_wor_1, uniq_count_1  = np.unique(df[columns[1]], return_counts = True)
        print (uniq_wor_0,uniq_count_0,'\n...\n',uniq_wor_1,uniq_count_1)      # test printing
        
        
        #    return 0
        
        # sepertion o each element and creation of array for entropy calculation
        entr_arr = np.array([])
        if len (uniq_wor_0) == 1:
            entr_arr = np.array([0])
        else:
            # checking the positive of pridection class with given atteibute
            for i in uniq_wor_1:
                print (i)
                arry_1 = (df[columns[0]] == uniq_wor_0[1])   # array of yes == true in play
                arry_2 = (df[columns[1]] == i)
                #print (arry_1.to_numpy().T)
                #print (arry_2.to_numpy().T)
                # getting the array where both atteibutes are positive
                result = np.logical_and(arry_1.to_numpy(), arry_2.to_numpy())
                #print (result.T)
                #print (result.sum())
                #print (arry_2.sum())
                #calculating the gini index of positives 
                result1 = (result.sum())/(arry_2.sum())
                #print (result)
                #temp_arr = np.append(temp_arr,result1)
                # making the dictionary of unique words and passing in to class function to calculate entropy
                prob_dic =  {uniq_wor_0[1]:(result1) , uniq_wor_0[0]:(1-result1) }
                ans = self.entropy (prob_dic)
                #normalizing the entropy by the weights of value
                norm_ent = (sum (arry_2)/len(arry_2)) * ans
                ##
                ## this array stores the value of entropies of all unique values with their relitive weights
                entr_arr = np.append(entr_arr, norm_ent)

                #print ("prob_dic =====>  ", prob_dic," === ans ===>", ans,"=== entr_arr ===>", entr_arr )

            #################################################
        
        print ("entr_arr == > ", entr_arr)
        
        dep_entr = entr_arr[:]
        # creating the data reame for primary key and passing it for praimary entropy 
        prim_att_df = pd.DataFrame()
        prim_att_df [self.target_attr] = df [self.target_attr]
        #print ("prim_att_df------->", prim_att_df)
        #prim_attr_dic = self.pmf_target(pd.DataFrame(prim_att_df))
        prim_attr_dic = self.pmf_target(prim_att_df)
        entp_prim = self.entropy(prim_attr_dic)
        
        #print ("prim_attr_dic ", prim_attr_dic, " entp_prim ", entp_prim)
        gain = entp_prim - sum(dep_entr)
        
        #print ("prim_attr_dic ", prim_attr_dic, "\n entp_prim ", entp_prim, "\n gain ", gain)
        
        #print ("-------------------\n")
        entr = gain
        return entr
    
    
    def info_gain_attribute(self, df: pd.DataFrame, attribute: str) -> float:
        # Add your code
        gain_info = np.array([])
        max_val = 0
        col = 'null'
        #going to every column and calculating the gain of each each attribute
        for i in attribute:
            df_col = pd.DataFrame()
            df_col[self.target_attr] = df[self.target_attr]
            df_col[i] = df[i]
            ans = self.cal_entropy_df (df_col)
            print("ans == > ", ans, type(ans))
            if (max_val < ans):
                max_val = ans
                print("max_val == > ", max_val)
                col = i
            gain_info = np.append(gain_info, ans)
        
        print ("gain_info--=>", gain_info)
        information_gain = col
        return information_gain
     
        
    def max_info_gain_attribute(self, df: pd.DataFrame) -> str:        
        # Add your code
        columns = df.columns
        columns = columns.drop(self.target_attr)
        gain_of_all = self.info_gain_attribute(df, columns)
        #max = gain_of_all.max()
        #print ("max ====> ",max_attr)
        print ("gain_of_all ===> ",gain_of_all, type (gain_of_all))
        max_arr = gain_of_all
        if (max_arr in df.columns):
            return max_arr
        else:
            return 'NULL'
    
    def build_tree_infgain(self, df: pd.DataFrame, attr_list: List[str], start_node: DecTreeNode):
        # Add your code
        if len(attr_list) == 2:
            return 0
        
        max_val_attr = self.max_info_gain_attribute(df)
        if (max_val_attr == "NULL"):
            DecTreeNode ((df[self.target_attr].unique())[0],'class',start_node)
            return 0
        
        print (" ------------------------------------\n\n")
        print ("in buit tree function==> max_val_attriubutr = ",max_val_attr)
        uniq_vale_max_attr = df[max_val_attr].unique ()
        print ("\nunique val " ,  uniq_vale_max_attr)
        for i in uniq_vale_max_attr:
            tree_node =  DecTreeNode (i, max_val_attr , start_node)
            new_df = df.copy()
            new_df.drop(df[df[max_val_attr] != i].index, inplace= True)
            new_df.drop(max_val_attr, axis = 1, inplace= True)
            print (new_df)
            self.build_tree_infgain (new_df, new_df.columns.to_list(), tree_node)
            
        # Use return to end current recursive call when any stopping condition is reached
        return
    
    def generate_tree(self):
        attributes = self.data.columns.to_list()
        attributes.remove(self.target_attr)
        
        start_node = DecTreeNode("start", "start")
        self.build_tree_infgain(self.data, attributes, start_node)
        
        self.root_node = start_node
    
    def print_tree(self):
        for pre, _, node in RenderTree(self.root_node):
            print(f"{pre} {node.attribute}={node.name}")
            
    def predict(self, X: pd.DataFrame) -> List[str]:
        # Add your code
        return predictions
            
        
dec_tree = DecTree(data , 'play')

dec_tree.generate_tree()
dec_tree.print_tree()
# Out:
# ['no' 'yes'] [5 9]
# ...
#  ['overcast' 'rainy' 'sunny'] [4 5 5]
# overcast
# rainy
# sunny
# entr_arr == >  [-0.          0.34676807  0.34676807]
# ans == >  0.24674981977443933 <class 'numpy.float64'>
# max_val == >  0.24674981977443933
# ['no' 'yes'] [5 9]
# ...
#  ['cool' 'hot' 'mild'] [4 4 6]
# cool
# hot
# mild
# entr_arr == >  [0.23179375 0.28571429 0.39355536]
# ans == >  0.02922256565895487 <class 'numpy.float64'>
# ['no' 'yes'] [5 9]
# ...
#  ['high' 'normal'] [7 7]
# high
# normal
# entr_arr == >  [0.49261407 0.29583639]
# ans == >  0.15183550136234159 <class 'numpy.float64'>
# ['no' 'yes'] [5 9]
# ...
#  [False  True] [8 6]
# False
# True
# entr_arr == >  [0.4635875  0.42857143]
# ans == >  0.04812703040826949 <class 'numpy.float64'>
# gain_info--=> [0.24674982 0.02922257 0.1518355  0.04812703]
# gain_of_all ===>  outlook <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  outlook
#
# unique val  ['sunny' 'overcast' 'rainy']
#     temp humidity  windy play
# 0    hot     high  False   no
# 1    hot     high   True   no
# 7   mild     high  False   no
# 8   cool   normal  False  yes
# 10  mild   normal   True  yes
# ['no' 'yes'] [3 2]
# ...
#  ['cool' 'hot' 'mild'] [1 2 2]
# cool
# hot
# mild
# entr_arr == >  [-0.  -0.   0.4]
# ans == >  0.5709505944546686 <class 'numpy.float64'>
# max_val == >  0.5709505944546686
# ['no' 'yes'] [3 2]
# ...
#  ['high' 'normal'] [3 2]
# high
# normal
# entr_arr == >  [-0. -0.]
# ans == >  0.9709505944546686 <class 'numpy.float64'>
# max_val == >  0.9709505944546686
# ['no' 'yes'] [3 2]
# ...
#  [False  True] [3 2]
# False
# True
# entr_arr == >  [0.5509775 0.4      ]
# ans == >  0.01997309402197489 <class 'numpy.float64'>
# gain_info--=> [0.57095059 0.97095059 0.01997309]
# gain_of_all ===>  humidity <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  humidity
#
# unique val  ['high' 'normal']
#    temp  windy play
# 0   hot  False   no
# 1   hot   True   no
# 7  mild  False   no
# ['no'] [3]
# ...
#  ['hot' 'mild'] [2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['no'] [3]
# ...
#  [False  True] [2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     temp  windy play
# 8   cool  False  yes
# 10  mild   True  yes
# ['yes'] [2]
# ...
#  ['cool' 'mild'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['yes'] [2]
# ...
#  [False  True] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     temp humidity  windy play
# 2    hot     high  False  yes
# 6   cool   normal   True  yes
# 11  mild     high   True  yes
# 12   hot   normal  False  yes
# ['yes'] [4]
# ...
#  ['cool' 'hot' 'mild'] [1 2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['yes'] [4]
# ...
#  ['high' 'normal'] [2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['yes'] [4]
# ...
#  [False  True] [2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0. -0.]
# gain_of_all ===>  null <class 'str'>
#     temp humidity  windy play
# 3   mild     high  False  yes
# 4   cool   normal  False  yes
# 5   cool   normal   True   no
# 9   mild   normal  False  yes
# 13  mild     high   True   no
# ['no' 'yes'] [2 3]
# ...
#  ['cool' 'mild'] [2 3]
# cool
# mild
# entr_arr == >  [0.4       0.5509775]
# ans == >  0.01997309402197489 <class 'numpy.float64'>
# max_val == >  0.01997309402197489
# ['no' 'yes'] [2 3]
# ...
#  ['high' 'normal'] [2 3]
# high
# normal
# entr_arr == >  [0.4       0.5509775]
# ans == >  0.01997309402197489 <class 'numpy.float64'>
# ['no' 'yes'] [2 3]
# ...
#  [False  True] [3 2]
# False
# True
# entr_arr == >  [-0. -0.]
# ans == >  0.9709505944546686 <class 'numpy.float64'>
# max_val == >  0.9709505944546686
# gain_info--=> [0.01997309 0.01997309 0.97095059]
# gain_of_all ===>  windy <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  windy
#
# unique val  [False  True]
#    temp humidity play
# 3  mild     high  yes
# 4  cool   normal  yes
# 9  mild   normal  yes
# ['yes'] [3]
# ...
#  ['cool' 'mild'] [1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['yes'] [3]
# ...
#  ['high' 'normal'] [1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     temp humidity play
# 5   cool   normal   no
# 13  mild     high   no
# ['no'] [2]
# ...
#  ['cool' 'mild'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['no'] [2]
# ...
#  ['high' 'normal'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#  start=start
# ├──  outlook=sunny
# │   ├──  humidity=high
# │   │   └──  class=no
# │   └──  humidity=normal
# │       └──  class=yes
# ├──  outlook=overcast
# │   └──  class=yes
# └──  outlook=rainy
#     ├──  windy=False
#     │   └──  class=yes
#     └──  windy=True
#         └──  class=no

# %%
arr = data['play'].to_numpy()
array, value = np.unique(arr,return_counts = True)

# %%
d = dict(zip(array, value))

d
# Out:
# {'no': 5, 'yes': 9}

# %%
df_temp = data.copy()
td =df_temp.drop(df_temp[df_temp['outlook'] != 'sunny'].index)#, inplace=True)
print (td, )
# Out:
#    outlook  temp humidity  windy play
# 0    sunny   hot     high  False   no
# 1    sunny   hot     high   True   no
# 7    sunny  mild     high  False   no
# 8    sunny  cool   normal  False  yes
# 10   sunny  mild   normal   True  yes

# %%
'tmp' in df_temp.columns
# Out:
# False

# %%
start_node = DecTreeNode("start", "start", parent=None)
start_node

# %%
x = np.array([.01,2,3,4,5])
y = np.log2(x)
(y)
# Out:
# array([-6.64385619,  1.        ,  1.5849625 ,  2.        ,  2.32192809])

# %%
df = pd.DataFrame()
df['outlook'] = data['outlook']
df['play'] = data['play']
arr1 = (df['outlook'] == 'sunny')
arr2 =  (df['play'] == 'yes')
print (arr1.to_numpy().T)
print (arr2.to_numpy().T)
print(arr1.to_numpy() & arr2.to_numpy())

#df['play'] == 'yes'
#((df['temp'] == 'hot') and (df['play'] == 'yes'))
# Out:
# [ True  True False False False False False  True  True False  True False
#  False False]
# [False False  True  True  True False  True False  True  True  True  True
#   True False]
# [False False False False False False False False  True False  True False
#  False False]

# %%
#the class is initilized and then i have pass pmf_targetdf
dectree = DecTree(data , 'play')

df = pd.DataFrame()
df['temp'] = data['temp']
df['play'] = data['play']
df
dectree.pmf_target(df)
# Out:
# {'cool': 0.14285714285714285,
#  'hot': 0.14285714285714285,
#  'mild': 0.21428571428571427,
#  'no': 0.17857142857142858,
#  'yes': 0.32142857142857145}

# %%
dectree = DecTree(data , 'play')

df = pd.DataFrame()
#df['temp'] = data['temp']
df['play'] = data['play']
per_dict = dectree.pmf_target(df)

dectree.entropy(per_dict)
# Out:
# 0.9402859586706311

# %%
car_df = pd.read_csv('cars_train.csv')

car_tree = DecTree(car_df , 'decision')
car_tree.generate_tree()
# Out:
# ['acc' 'unacc'] [121 379]
# ...
#  ['high' 'low' 'med' 'vhigh'] [138  94 117 151]
# high
# low
# med
# vhigh
# entr_arr == >  [0.23149448 0.16264283 0.20082601 0.19079412]
# ans == >  0.012592985052895411 <class 'numpy.float64'>
# max_val == >  0.012592985052895411
# ['acc' 'unacc'] [121 379]
# ...
#  ['high' 'low' 'med' 'vhigh'] [134 108 124 134]
# high
# low
# med
# vhigh
# entr_arr == >  [0.21582317 0.16860635 0.22497711 0.17726773]
# ans == >  0.01167606219134032 <class 'numpy.float64'>
# ['acc' 'unacc'] [121 379]
# ...
#  ['2' '3' '4' '5more'] [126 142 117 115]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.16380565 0.20341738 0.20837504 0.20623075]
# ans == >  0.016521589765281064 <class 'numpy.float64'>
# max_val == >  0.016521589765281064
# ['acc' 'unacc'] [121 379]
# ...
#  ['2' '4' 'more'] [180 158 162]
# 2
# 4
# more
# entr_arr == >  [-0.          0.30123023  0.31101982]
# ans == >  0.18610037399274204 <class 'numpy.float64'>
# max_val == >  0.18610037399274204
# ['acc' 'unacc'] [121 379]
# ...
#  ['big' 'med' 'small'] [152 167 181]
# big
# med
# small
# entr_arr == >  [0.25569038 0.26189586 0.2794257 ]
# ans == >  0.0013384803135790824 <class 'numpy.float64'>
# ['acc' 'unacc'] [121 379]
# ...
#  ['high' 'low' 'med'] [159 176 165]
# high
# low
# med
# entr_arr == >  [ 0.31471661 -0.          0.29440002]
# ans == >  0.18923379102137117 <class 'numpy.float64'>
# max_val == >  0.18923379102137117
# gain_info--=> [0.01259299 0.01167606 0.01652159 0.18610037 0.00133848 0.18923379]
# gain_of_all ===>  safety <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  safety
#
# unique val  ['high' 'low' 'med']
#     buying_price maintenance_cost num_doors num_persons size_luggage decision
# 0            med            vhigh         2        more        small    unacc
# 2            med              med         2           4          med      acc
# 3           high            vhigh         2        more        small    unacc
# 4          vhigh              med         2           4        small      acc
# 5           high              med         4           4        small      acc
# ..           ...              ...       ...         ...          ...      ...
# 474        vhigh              low         3           2        small    unacc
# 479          med            vhigh         3           4        small      acc
# 483        vhigh              low         3        more        small      acc
# 497        vhigh            vhigh         4           2          med    unacc
# 499        vhigh            vhigh         3           2        small    unacc
#
# [159 rows x 6 columns]
# ['acc' 'unacc'] [70 89]
# ...
#  ['high' 'low' 'med' 'vhigh'] [52 29 29 49]
# high
# low
# med
# vhigh
# entr_arr == >  [0.32669496 0.17464812 0.18097945 0.29233992]
# ans == >  0.015012421655452135 <class 'numpy.float64'>
# max_val == >  0.015012421655452135
# ['acc' 'unacc'] [70 89]
# ...
#  ['high' 'low' 'med' 'vhigh'] [42 33 30 54]
# high
# low
# med
# vhigh
# entr_arr == >  [0.26242003 0.20075929 0.1662813  0.30520303]
# ans == >  0.05501120985294505 <class 'numpy.float64'>
# max_val == >  0.05501120985294505
# ['acc' 'unacc'] [70 89]
# ...
#  ['2' '3' '4' '5more'] [42 43 36 38]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.23578721 0.26183071 0.22439458 0.23851593]
# ans == >  0.029146424938942705 <class 'numpy.float64'>
# ['acc' 'unacc'] [70 89]
# ...
#  ['2' '4' 'more'] [59 44 56]
# 2
# 4
# more
# entr_arr == >  [-0.          0.22450464  0.325481  ]
# ans == >  0.4396892296875916 <class 'numpy.float64'>
# max_val == >  0.4396892296875916
# ['acc' 'unacc'] [70 89]
# ...
#  ['big' 'med' 'small'] [43 57 59]
# big
# med
# small
# entr_arr == >  [0.26524736 0.35649819 0.36729246]
# ans == >  0.0006368544063836135 <class 'numpy.float64'>
# gain_info--=> [0.01501242 0.05501121 0.02914642 0.43968923 0.00063685]
# gain_of_all ===>  num_persons <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  num_persons
#
# unique val  ['more' '4' '2']
#     buying_price maintenance_cost num_doors size_luggage decision
# 0            med            vhigh         2        small    unacc
# 3           high            vhigh         2        small    unacc
# 29          high              low         4        small      acc
# 30           med            vhigh     5more        small      acc
# 31         vhigh              low         4          med      acc
# 41           med              med     5more        small      acc
# 43          high             high     5more          med      acc
# 57          high             high         3        small      acc
# 68         vhigh              med         3          big      acc
# 77          high              med         3          med      acc
# 91           med            vhigh         3          big      acc
# 92           med             high         4          med      acc
# 101        vhigh              low         3          med      acc
# 110         high            vhigh     5more          big    unacc
# 113          med            vhigh         4        small      acc
# 130         high              med     5more        small      acc
# 134        vhigh             high     5more        small    unacc
# 138        vhigh              med     5more        small      acc
# 142        vhigh              low         3          big      acc
# 151         high            vhigh         3          med    unacc
# 170          low            vhigh         3          med      acc
# 178         high             high         2          med      acc
# 182        vhigh             high         2          med    unacc
# 192         high             high         2          big      acc
# 212        vhigh            vhigh         4        small    unacc
# 217         high              med     5more          big      acc
# 224         high              low     5more          med      acc
# 227         high            vhigh     5more        small    unacc
# 236         high            vhigh         2          med    unacc
# 237          med             high     5more        small      acc
# 238        vhigh            vhigh     5more          big    unacc
# 239          med             high     5more          med      acc
# 244        vhigh              med         4        small      acc
# 270        vhigh              med     5more          med      acc
# 277          med              med         4        small      acc
# 288         high             high         4          med      acc
# 293         high             high     5more          big      acc
# 294          med            vhigh         3        small      acc
# 295          low              med         2        small    unacc
# 296         high            vhigh         4        small    unacc
# 303         high              med         3          big      acc
# 307         high              low         2          med      acc
# 319          low            vhigh         4        small      acc
# 357         high            vhigh         2          big    unacc
# 364        vhigh            vhigh         2          big    unacc
# 372          low            vhigh     5more        small      acc
# 379        vhigh              low         2        small    unacc
# 381        vhigh            vhigh         3          med    unacc
# 394          low            vhigh         2          med      acc
# 402        vhigh              low         4          big      acc
# 416         high            vhigh         4          big    unacc
# 420        vhigh            vhigh         3          big    unacc
# 421          med            vhigh     5more          med      acc
# 437         high             high         4          big      acc
# 466         high              low         2        small    unacc
# 483        vhigh              low         3        small      acc
# ['acc' 'unacc'] [37 19]
# ...
#  ['high' 'low' 'med' 'vhigh'] [23  5 11 17]
# high
# low
# med
# vhigh
# entr_arr == >  [0.39660055 0.06445787 0.08632977 0.30281327]
# ans == >  0.0739320833063235 <class 'numpy.float64'>
# max_val == >  0.0739320833063235
# ['acc' 'unacc'] [37 19]
# ...
#  ['high' 'low' 'med' 'vhigh'] [12 10 11 23]
# high
# low
# med
# vhigh
# entr_arr == >  [0.13929052 0.12891573 0.08632977 0.39660055]
# ans == >  0.17299697177164308 <class 'numpy.float64'>
# max_val == >  0.17299697177164308
# ['acc' 'unacc'] [37 19]
# ...
#  ['2' '3' '4' '5more'] [13 13 13 17]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.20672127 0.1809205  0.1809205  0.23894914]
# ans == >  0.1166221302438819 <class 'numpy.float64'>
# ['acc' 'unacc'] [37 19]
# ...
#  ['big' 'med' 'small'] [15 18 23]
# big
# med
# small
# entr_arr == >  [0.26007605 0.24563716 0.39660055]
# ans == >  0.021819772321916897 <class 'numpy.float64'>
# gain_info--=> [0.07393208 0.17299697 0.11662213 0.02181977]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['vhigh' 'low' 'med' 'high']
#     buying_price num_doors size_luggage decision
# 0            med         2        small    unacc
# 3           high         2        small    unacc
# 30           med     5more        small      acc
# 91           med         3          big      acc
# 110         high     5more          big    unacc
# 113          med         4        small      acc
# 151         high         3          med    unacc
# 170          low         3          med      acc
# 212        vhigh         4        small    unacc
# 227         high     5more        small    unacc
# 236         high         2          med    unacc
# 238        vhigh     5more          big    unacc
# 294          med         3        small      acc
# 296         high         4        small    unacc
# 319          low         4        small      acc
# 357         high         2          big    unacc
# 364        vhigh         2          big    unacc
# 372          low     5more        small      acc
# 381        vhigh         3          med    unacc
# 394          low         2          med      acc
# 416         high         4          big    unacc
# 420        vhigh         3          big    unacc
# 421          med     5more          med      acc
# ['acc' 'unacc'] [ 9 14]
# ...
#  ['high' 'low' 'med' 'vhigh'] [8 4 6 5]
# high
# low
# med
# vhigh
# entr_arr == >  [-0.         -0.          0.16957107 -0.        ]
# ans == >  0.7960650668536479 <class 'numpy.float64'>
# max_val == >  0.7960650668536479
# ['acc' 'unacc'] [ 9 14]
# ...
#  ['2' '3' '4' '5more'] [6 6 5 6]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.16957107 0.26086957 0.21107622 0.26086957]
# ans == >  0.06324972023306774 <class 'numpy.float64'>
# ['acc' 'unacc'] [ 9 14]
# ...
#  ['big' 'med' 'small'] [ 7  6 10]
# big
# med
# small
# entr_arr == >  [0.18007432 0.26086957 0.43478261]
# ans == >  0.0899096355412059 <class 'numpy.float64'>
# gain_info--=> [0.79606507 0.06324972 0.08990964]
# gain_of_all ===>  buying_price <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  buying_price
#
# unique val  ['med' 'high' 'low' 'vhigh']
#     num_doors size_luggage decision
# 0           2        small    unacc
# 30      5more        small      acc
# 91          3          big      acc
# 113         4        small      acc
# 294         3        small      acc
# 421     5more          med      acc
# ['acc' 'unacc'] [5 1]
# ...
#  ['2' '3' '4' '5more'] [1 2 1 2]
# 2
# 3
# 4
# 5more
# entr_arr == >  [-0. -0. -0. -0.]
# ans == >  0.6500224216483541 <class 'numpy.float64'>
# max_val == >  0.6500224216483541
# ['acc' 'unacc'] [5 1]
# ...
#  ['big' 'med' 'small'] [1 1 4]
# big
# med
# small
# entr_arr == >  [-0.         -0.          0.54085208]
# ans == >  0.10917033867559889 <class 'numpy.float64'>
# gain_info--=> [0.65002242 0.10917034]
# gain_of_all ===>  num_doors <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  num_doors
#
# unique val  ['2' '5more' '3' '4']
#   size_luggage decision
# 0        small    unacc
#     size_luggage decision
# 30         small      acc
# 421          med      acc
#     size_luggage decision
# 91           big      acc
# 294        small      acc
#     size_luggage decision
# 113        small      acc
#     num_doors size_luggage decision
# 3           2        small    unacc
# 110     5more          big    unacc
# 151         3          med    unacc
# 227     5more        small    unacc
# 236         2          med    unacc
# 296         4        small    unacc
# 357         2          big    unacc
# 416         4          big    unacc
# ['unacc'] [8]
# ...
#  ['2' '3' '4' '5more'] [3 1 2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [8]
# ...
#  ['big' 'med' 'small'] [3 2 3]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 170         3          med      acc
# 319         4        small      acc
# 372     5more        small      acc
# 394         2          med      acc
# ['acc'] [4]
# ...
#  ['2' '3' '4' '5more'] [1 1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [4]
# ...
#  ['med' 'small'] [2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 212         4        small    unacc
# 238     5more          big    unacc
# 364         2          big    unacc
# 381         3          med    unacc
# 420         3          big    unacc
# ['unacc'] [5]
# ...
#  ['2' '3' '4' '5more'] [1 2 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [5]
# ...
#  ['big' 'med' 'small'] [3 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price num_doors size_luggage decision
# 29          high         4        small      acc
# 31         vhigh         4          med      acc
# 101        vhigh         3          med      acc
# 142        vhigh         3          big      acc
# 224         high     5more          med      acc
# 307         high         2          med      acc
# 379        vhigh         2        small    unacc
# 402        vhigh         4          big      acc
# 466         high         2        small    unacc
# 483        vhigh         3        small      acc
# ['acc' 'unacc'] [8 2]
# ...
#  ['high' 'vhigh'] [4 6]
# high
# vhigh
# entr_arr == >  [0.32451125 0.39001345]
# ans == >  0.007403392114696761 <class 'numpy.float64'>
# max_val == >  0.007403392114696761
# ['acc' 'unacc'] [8 2]
# ...
#  ['2' '3' '4' '5more'] [3 3 3 1]
# 2
# 3
# 4
# 5more
# entr_arr == >  [ 0.27548875 -0.         -0.         -0.        ]
# ans == >  0.4464393446710155 <class 'numpy.float64'>
# max_val == >  0.4464393446710155
# ['acc' 'unacc'] [8 2]
# ...
#  ['big' 'med' 'small'] [2 4 4]
# big
# med
# small
# entr_arr == >  [-0.  -0.   0.4]
# ans == >  0.3219280948873623 <class 'numpy.float64'>
# gain_info--=> [0.00740339 0.44643934 0.32192809]
# gain_of_all ===>  num_doors <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  num_doors
#
# unique val  ['4' '3' '5more' '2']
#     buying_price size_luggage decision
# 29          high        small      acc
# 31         vhigh          med      acc
# 402        vhigh          big      acc
# ['acc'] [3]
# ...
#  ['high' 'vhigh'] [1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [3]
# ...
#  ['big' 'med' 'small'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price size_luggage decision
# 101        vhigh          med      acc
# 142        vhigh          big      acc
# 483        vhigh        small      acc
# ['acc'] [3]
# ...
#  ['vhigh'] [3]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [3]
# ...
#  ['big' 'med' 'small'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price size_luggage decision
# 224         high          med      acc
# ['acc'] [1]
# ...
#  ['high'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [1]
# ...
#  ['med'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price size_luggage decision
# 307         high          med      acc
# 379        vhigh        small    unacc
# 466         high        small    unacc
# ['acc' 'unacc'] [1 2]
# ...
#  ['high' 'vhigh'] [2 1]
# high
# vhigh
# entr_arr == >  [ 0.66666667 -0.        ]
# ans == >  0.2516291673878229 <class 'numpy.float64'>
# max_val == >  0.2516291673878229
# ['acc' 'unacc'] [1 2]
# ...
#  ['med' 'small'] [1 2]
# med
# small
# entr_arr == >  [-0. -0.]
# ans == >  0.9182958340544896 <class 'numpy.float64'>
# max_val == >  0.9182958340544896
# gain_info--=> [0.25162917 0.91829583]
# gain_of_all ===>  size_luggage <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  size_luggage
#
# unique val  ['med' 'small']
#     buying_price decision
# 307         high      acc
#     buying_price decision
# 379        vhigh    unacc
# 466         high    unacc
#     buying_price num_doors size_luggage decision
# 41           med     5more        small      acc
# 68         vhigh         3          big      acc
# 77          high         3          med      acc
# 130         high     5more        small      acc
# 138        vhigh     5more        small      acc
# 217         high     5more          big      acc
# 244        vhigh         4        small      acc
# 270        vhigh     5more          med      acc
# 277          med         4        small      acc
# 295          low         2        small    unacc
# 303         high         3          big      acc
# ['acc' 'unacc'] [10  1]
# ...
#  ['high' 'low' 'med' 'vhigh'] [4 1 2 4]
# high
# low
# med
# vhigh
# entr_arr == >  [-0. -0. -0. -0.]
# ans == >  0.4394969869215134 <class 'numpy.float64'>
# max_val == >  0.4394969869215134
# ['acc' 'unacc'] [10  1]
# ...
#  ['2' '3' '4' '5more'] [1 3 2 5]
# 2
# 3
# 4
# 5more
# entr_arr == >  [-0. -0. -0. -0.]
# ans == >  0.4394969869215134 <class 'numpy.float64'>
# ['acc' 'unacc'] [10  1]
# ...
#  ['big' 'med' 'small'] [3 2 6]
# big
# med
# small
# entr_arr == >  [-0.         -0.          0.35455768]
# ans == >  0.08493930238604752 <class 'numpy.float64'>
# gain_info--=> [0.43949699 0.43949699 0.0849393 ]
# gain_of_all ===>  buying_price <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  buying_price
#
# unique val  ['med' 'vhigh' 'high' 'low']
#     num_doors size_luggage decision
# 41      5more        small      acc
# 277         4        small      acc
# ['acc'] [2]
# ...
#  ['4' '5more'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [2]
# ...
#  ['small'] [2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 68          3          big      acc
# 138     5more        small      acc
# 244         4        small      acc
# 270     5more          med      acc
# ['acc'] [4]
# ...
#  ['3' '4' '5more'] [1 1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [4]
# ...
#  ['big' 'med' 'small'] [1 1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 77          3          med      acc
# 130     5more        small      acc
# 217     5more          big      acc
# 303         3          big      acc
# ['acc'] [4]
# ...
#  ['3' '5more'] [2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [4]
# ...
#  ['big' 'med' 'small'] [2 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 295         2        small    unacc
# ['unacc'] [1]
# ...
#  ['2'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [1]
# ...
#  ['small'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price num_doors size_luggage decision
# 43          high     5more          med      acc
# 57          high         3        small      acc
# 92           med         4          med      acc
# 134        vhigh     5more        small    unacc
# 178         high         2          med      acc
# 182        vhigh         2          med    unacc
# 192         high         2          big      acc
# 237          med     5more        small      acc
# 239          med     5more          med      acc
# 288         high         4          med      acc
# 293         high     5more          big      acc
# 437         high         4          big      acc
# ['acc' 'unacc'] [10  2]
# ...
#  ['high' 'med' 'vhigh'] [7 3 2]
# high
# med
# vhigh
# entr_arr == >  [-0. -0. -0.]
# ans == >  0.6500224216483541 <class 'numpy.float64'>
# max_val == >  0.6500224216483541
# ['acc' 'unacc'] [10  2]
# ...
#  ['2' '3' '4' '5more'] [3 1 3 5]
# 2
# 3
# 4
# 5more
# entr_arr == >  [ 0.22957396 -0.         -0.          0.30080337]
# ans == >  0.11964509026499748 <class 'numpy.float64'>
# ['acc' 'unacc'] [10  2]
# ...
#  ['big' 'med' 'small'] [3 6 3]
# big
# med
# small
# entr_arr == >  [-0.          0.32501121  0.22957396]
# ans == >  0.09543725231055467 <class 'numpy.float64'>
# gain_info--=> [0.65002242 0.11964509 0.09543725]
# gain_of_all ===>  buying_price <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  buying_price
#
# unique val  ['high' 'med' 'vhigh']
#     num_doors size_luggage decision
# 43      5more          med      acc
# 57          3        small      acc
# 178         2          med      acc
# 192         2          big      acc
# 288         4          med      acc
# 293     5more          big      acc
# 437         4          big      acc
# ['acc'] [7]
# ...
#  ['2' '3' '4' '5more'] [2 1 2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [7]
# ...
#  ['big' 'med' 'small'] [3 3 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 92          4          med      acc
# 237     5more        small      acc
# 239     5more          med      acc
# ['acc'] [3]
# ...
#  ['4' '5more'] [1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [3]
# ...
#  ['med' 'small'] [2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 134     5more        small    unacc
# 182         2          med    unacc
# ['unacc'] [2]
# ...
#  ['2' '5more'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [2]
# ...
#  ['med' 'small'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price maintenance_cost num_doors size_luggage decision
# 2            med              med         2          med      acc
# 4          vhigh              med         2        small      acc
# 5           high              med         4        small      acc
# 34          high              med     5more          big      acc
# 74         vhigh              med     5more        small      acc
# 87           low            vhigh         2          med      acc
# 103          low            vhigh         2        small      acc
# 120         high              low         4          med      acc
# 147        vhigh              low         3        small      acc
# 148          low            vhigh         4          big      acc
# 154          low            vhigh     5more          big      acc
# 167        vhigh             high         3          big    unacc
# 193         high              med     5more          med      acc
# 196         high             high         2          med      acc
# 210         high              med         3          med      acc
# 233        vhigh              med         2          med      acc
# 241          low            vhigh     5more          med      acc
# 278        vhigh              low         3          big      acc
# 279         high             high         4        small      acc
# 282        vhigh            vhigh     5more        small    unacc
# 308        vhigh              med         3          med      acc
# 313        vhigh              low         4        small      acc
# 331         high             high         4          big      acc
# 344         high             high         2        small      acc
# 350          med             high         4          med      acc
# 352         high            vhigh     5more          big    unacc
# 356          med              med         3          med      acc
# 368        vhigh             high     5more          big    unacc
# 377         high            vhigh         4        small    unacc
# 390          med            vhigh     5more          med      acc
# 396         high             high         2          big      acc
# 400        vhigh             high         4          big    unacc
# 414          med             high         2          big      acc
# 417        vhigh            vhigh         3        small    unacc
# 422        vhigh             high         3          med    unacc
# 428          low            vhigh         3        small      acc
# 432        vhigh             high         2          big    unacc
# 436         high             high     5more          big      acc
# 439          low             high         4        small      acc
# 441         high            vhigh         3          med    unacc
# 446        vhigh              low         4          big      acc
# 464        vhigh            vhigh         2        small    unacc
# 468        vhigh              med         4        small      acc
# 479          med            vhigh         3        small      acc
# ['acc' 'unacc'] [33 11]
# ...
#  ['high' 'low' 'med' 'vhigh'] [14  7  6 17]
# high
# low
# med
# vhigh
# entr_arr == >  [ 0.23850758 -0.         -0.          0.38539871]
# ans == >  0.18737183150668557 <class 'numpy.float64'>
# max_val == >  0.18737183150668557
# ['acc' 'unacc'] [33 11]
# ...
#  ['high' 'low' 'med' 'vhigh'] [14  5 11 14]
# high
# low
# med
# vhigh
# entr_arr == >  [ 0.2991819  -0.         -0.          0.31348168]
# ans == >  0.19861454887121555 <class 'numpy.float64'>
# max_val == >  0.19861454887121555
# ['acc' 'unacc'] [33 11]
# ...
#  ['2' '3' '4' '5more'] [11 11 12 10]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.17100961 0.23641508 0.17727884 0.20029339]
# ans == >  0.02628121094268565 <class 'numpy.float64'>
# ['acc' 'unacc'] [33 11]
# ...
#  ['big' 'med' 'small'] [14 14 16]
# big
# med
# small
# entr_arr == >  [0.2991819  0.18825952 0.29501023]
# ans == >  0.02882648098441598 <class 'numpy.float64'>
# gain_info--=> [0.18737183 0.19861455 0.02628121 0.02882648]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['med' 'vhigh' 'low' 'high']
#     buying_price num_doors size_luggage decision
# 2            med         2          med      acc
# 4          vhigh         2        small      acc
# 5           high         4        small      acc
# 34          high     5more          big      acc
# 74         vhigh     5more        small      acc
# 193         high     5more          med      acc
# 210         high         3          med      acc
# 233        vhigh         2          med      acc
# 308        vhigh         3          med      acc
# 356          med         3          med      acc
# 468        vhigh         4        small      acc
# ['acc'] [11]
# ...
#  ['high' 'med' 'vhigh'] [4 2 5]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [11]
# ...
#  ['2' '3' '4' '5more'] [3 3 2 3]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [11]
# ...
#  ['big' 'med' 'small'] [1 6 4]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price num_doors size_luggage decision
# 87           low         2          med      acc
# 103          low         2        small      acc
# 148          low         4          big      acc
# 154          low     5more          big      acc
# 241          low     5more          med      acc
# 282        vhigh     5more        small    unacc
# 352         high     5more          big    unacc
# 377         high         4        small    unacc
# 390          med     5more          med      acc
# 417        vhigh         3        small    unacc
# 428          low         3        small      acc
# 441         high         3          med    unacc
# 464        vhigh         2        small    unacc
# 479          med         3        small      acc
# ['acc' 'unacc'] [8 6]
# ...
#  ['high' 'low' 'med' 'vhigh'] [3 6 2 3]
# high
# low
# med
# vhigh
# entr_arr == >  [-0. -0. -0. -0.]
# ans == >  0.9852281360342515 <class 'numpy.float64'>
# max_val == >  0.9852281360342515
# ['acc' 'unacc'] [8 6]
# ...
#  ['2' '3' '4' '5more'] [3 4 2 5]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.19677768 0.28571429 0.14285714 0.34676807]
# ans == >  0.013110959288765045 <class 'numpy.float64'>
# ['acc' 'unacc'] [8 6]
# ...
#  ['big' 'med' 'small'] [3 4 7]
# big
# med
# small
# entr_arr == >  [0.19677768 0.23179375 0.49261407]
# ans == >  0.06404263944569721 <class 'numpy.float64'>
# gain_info--=> [0.98522814 0.01311096 0.06404264]
# gain_of_all ===>  buying_price <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  buying_price
#
# unique val  ['low' 'vhigh' 'high' 'med']
#     num_doors size_luggage decision
# 87          2          med      acc
# 103         2        small      acc
# 148         4          big      acc
# 154     5more          big      acc
# 241     5more          med      acc
# 428         3        small      acc
# ['acc'] [6]
# ...
#  ['2' '3' '4' '5more'] [2 1 1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [6]
# ...
#  ['big' 'med' 'small'] [2 2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 282     5more        small    unacc
# 417         3        small    unacc
# 464         2        small    unacc
# ['unacc'] [3]
# ...
#  ['2' '3' '5more'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [3]
# ...
#  ['small'] [3]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 352     5more          big    unacc
# 377         4        small    unacc
# 441         3          med    unacc
# ['unacc'] [3]
# ...
#  ['3' '4' '5more'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [3]
# ...
#  ['big' 'med' 'small'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 390     5more          med      acc
# 479         3        small      acc
# ['acc'] [2]
# ...
#  ['3' '5more'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [2]
# ...
#  ['med' 'small'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price num_doors size_luggage decision
# 120         high         4          med      acc
# 147        vhigh         3        small      acc
# 278        vhigh         3          big      acc
# 313        vhigh         4        small      acc
# 446        vhigh         4          big      acc
# ['acc'] [5]
# ...
#  ['high' 'vhigh'] [1 4]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [5]
# ...
#  ['3' '4'] [2 3]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [5]
# ...
#  ['big' 'med' 'small'] [2 1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price num_doors size_luggage decision
# 167        vhigh         3          big    unacc
# 196         high         2          med      acc
# 279         high         4        small      acc
# 331         high         4          big      acc
# 344         high         2        small      acc
# 350          med         4          med      acc
# 368        vhigh     5more          big    unacc
# 396         high         2          big      acc
# 400        vhigh         4          big    unacc
# 414          med         2          big      acc
# 422        vhigh         3          med    unacc
# 432        vhigh         2          big    unacc
# 436         high     5more          big      acc
# 439          low         4        small      acc
# ['acc' 'unacc'] [9 5]
# ...
#  ['high' 'low' 'med' 'vhigh'] [6 1 2 5]
# high
# low
# med
# vhigh
# entr_arr == >  [-0. -0. -0. -0.]
# ans == >  0.9402859586706311 <class 'numpy.float64'>
# max_val == >  0.9402859586706311
# ['acc' 'unacc'] [9 5]
# ...
#  ['2' '3' '4' '5more'] [5 2 5 2]
# 2
# 3
# 4
# 5more
# entr_arr == >  [ 0.25783146 -0.          0.25783146  0.14285714]
# ans == >  0.28176589089394377 <class 'numpy.float64'>
# ['acc' 'unacc'] [9 5]
# ...
#  ['big' 'med' 'small'] [8 3 3]
# big
# med
# small
# entr_arr == >  [ 0.57142857  0.19677768 -0.        ]
# ans == >  0.17207970851609766 <class 'numpy.float64'>
# gain_info--=> [0.94028596 0.28176589 0.17207971]
# gain_of_all ===>  buying_price <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  buying_price
#
# unique val  ['vhigh' 'high' 'med' 'low']
#     num_doors size_luggage decision
# 167         3          big    unacc
# 368     5more          big    unacc
# 400         4          big    unacc
# 422         3          med    unacc
# 432         2          big    unacc
# ['unacc'] [5]
# ...
#  ['2' '3' '4' '5more'] [1 2 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [5]
# ...
#  ['big' 'med'] [4 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 196         2          med      acc
# 279         4        small      acc
# 331         4          big      acc
# 344         2        small      acc
# 396         2          big      acc
# 436     5more          big      acc
# ['acc'] [6]
# ...
#  ['2' '4' '5more'] [3 2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [6]
# ...
#  ['big' 'med' 'small'] [3 1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 350         4          med      acc
# 414         2          big      acc
# ['acc'] [2]
# ...
#  ['2' '4'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [2]
# ...
#  ['big' 'med'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 439         4        small      acc
# ['acc'] [1]
# ...
#  ['4'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [1]
# ...
#  ['small'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price maintenance_cost num_doors size_luggage decision
# 16           low             high         2        small    unacc
# 18          high              low         2          med    unacc
# 26           med              med         2          med    unacc
# 27          high             high         3          med    unacc
# 32         vhigh            vhigh         3          med    unacc
# 36           med              low     5more          big    unacc
# 44         vhigh             high         2        small    unacc
# 46          high            vhigh         4        small    unacc
# 50           low              low         3        small    unacc
# 54         vhigh              low     5more        small    unacc
# 58           low             high         2          med    unacc
# 67           low              low         4          med    unacc
# 73         vhigh            vhigh         4        small    unacc
# 76           med             high         3        small    unacc
# 80          high              low         2          big    unacc
# 85          high            vhigh         3          big    unacc
# 96         vhigh             high         4          med    unacc
# 117          low              low         4        small    unacc
# 123         high            vhigh         3        small    unacc
# 137          low             high         3        small    unacc
# 139          low              med     5more          med    unacc
# 145        vhigh              med         2          big    unacc
# 155        vhigh             high         3          med    unacc
# 158        vhigh             high         2          med    unacc
# 161          med              low         2        small    unacc
# 173         high             high     5more          big    unacc
# 174          med              low     5more          med    unacc
# 184          low              med         2        small    unacc
# 185          med            vhigh         2          big    unacc
# 203          low            vhigh     5more          med    unacc
# 204         high              low         3          med    unacc
# 221        vhigh            vhigh         2          med    unacc
# 231         high              low     5more        small    unacc
# 243         high            vhigh         3          med    unacc
# 248        vhigh            vhigh         3          big    unacc
# 250          med              low         2          med    unacc
# 269        vhigh              low         3          big    unacc
# 276          low              med     5more        small    unacc
# 291          med             high         2          med    unacc
# 301          med              low         4          med    unacc
# 304          low             high     5more          med    unacc
# 309         high              med         3          med    unacc
# 315         high             high         4          big    unacc
# 316          low            vhigh         4          med    unacc
# 322          low              low         2        small    unacc
# 327          low              med         2          med    unacc
# 355         high              med         4          med    unacc
# 360        vhigh              low         3          med    unacc
# 395          med            vhigh         3          big    unacc
# 427         high            vhigh         2          big    unacc
# 431          low             high         3          big    unacc
# 433          med            vhigh     5more        small    unacc
# 434          med             high         3          big    unacc
# 443          low             high         4        small    unacc
# 456          low              low         2          big    unacc
# 459         high            vhigh     5more        small    unacc
# 474        vhigh              low         3        small    unacc
# 497        vhigh            vhigh         4          med    unacc
# 499        vhigh            vhigh         3        small    unacc
# ['unacc'] [59]
# ...
#  ['high' 'low' 'med' 'vhigh'] [15 17 12 15]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [59]
# ...
#  ['high' 'low' 'med' 'vhigh'] [16 18  8 17]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [59]
# ...
#  ['2' '3' '4' '5more'] [18 19 11 11]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [59]
# ...
#  ['big' 'med' 'small'] [14 25 20]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0. -0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price maintenance_cost num_doors num_persons size_luggage decision
# 1           high            vhigh         3           2          big    unacc
# 6          vhigh             high     5more           2        small    unacc
# 7           high              low         3           2          big    unacc
# 9          vhigh              med         2           2          big    unacc
# 12          high              low         2           2          med    unacc
# ..           ...              ...       ...         ...          ...      ...
# 489          med            vhigh     5more           4          med    unacc
# 492          med            vhigh         2           4        small    unacc
# 494          med              med     5more           4        small    unacc
# 495        vhigh              med         4           2        small    unacc
# 498         high              med         2        more        small    unacc
#
# [176 rows x 6 columns]
# ['unacc'] [176]
# ...
#  ['high' 'low' 'med' 'vhigh'] [41 35 46 54]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [176]
# ...
#  ['high' 'low' 'med' 'vhigh'] [40 44 50 42]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [176]
# ...
#  ['2' '3' '4' '5more'] [45 57 38 36]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [176]
# ...
#  ['2' '4' 'more'] [61 60 55]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [176]
# ...
#  ['big' 'med' 'small'] [59 58 59]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0. -0. -0. -0.]
# gain_of_all ===>  null <class 'str'>
#     buying_price maintenance_cost num_doors num_persons size_luggage decision
# 8          vhigh            vhigh     5more        more        small    unacc
# 10           med             high         3           2        small    unacc
# 11          high              low         3        more          big      acc
# 14           low             high         3           4        small      acc
# 15          high             high         2           2        small    unacc
# ..           ...              ...       ...         ...          ...      ...
# 487         high              med         4           2          big    unacc
# 490         high              low         4           2          big    unacc
# 491          med             high     5more        more          big      acc
# 493         high              low         2        more          big      acc
# 496          low             high         3        more        small      acc
#
# [165 rows x 6 columns]
# ['acc' 'unacc'] [ 51 114]
# ...
#  ['high' 'low' 'med' 'vhigh'] [45 30 42 48]
# high
# low
# med
# vhigh
# entr_arr == >  [0.22817475 0.18123484 0.24784278 0.15812784]
# ans == >  0.07674107250767559 <class 'numpy.float64'>
# max_val == >  0.07674107250767559
# ['acc' 'unacc'] [ 51 114]
# ...
#  ['high' 'low' 'med' 'vhigh'] [52 31 44 38]
# high
# low
# med
# vhigh
# entr_arr == >  [0.26484031 0.18090856 0.26307857 0.144918  ]
# ans == >  0.03837583810226297 <class 'numpy.float64'>
# ['acc' 'unacc'] [ 51 114]
# ...
#  ['2' '3' '4' '5more'] [39 42 43 41]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.17303394 0.21117272 0.24816619 0.23977714]
# ans == >  0.019971289170568562 <class 'numpy.float64'>
# ['acc' 'unacc'] [ 51 114]
# ...
#  ['2' '4' 'more'] [60 54 51]
# 2
# 4
# more
# entr_arr == >  [-0.          0.32694882  0.30900518]
# ans == >  0.25616728268592137 <class 'numpy.float64'>
# max_val == >  0.25616728268592137
# ['acc' 'unacc'] [ 51 114]
# ...
#  ['big' 'med' 'small'] [50 52 63]
# big
# med
# small
# entr_arr == >  [0.30162983 0.25567553 0.30234592]
# ans == >  0.03247000406421274 <class 'numpy.float64'>
# gain_info--=> [0.07674107 0.03837584 0.01997129 0.25616728 0.03247   ]
# gain_of_all ===>  num_persons <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  num_persons
#
# unique val  ['more' '2' '4']
#     buying_price maintenance_cost num_doors size_luggage decision
# 8          vhigh            vhigh     5more        small    unacc
# 11          high              low         3          big      acc
# 20         vhigh            vhigh         2          big    unacc
# 21         vhigh             high         3        small    unacc
# 33           med              med         4          big      acc
# 35         vhigh              low         2        small    unacc
# 48         vhigh              med         4          med      acc
# 61           low            vhigh         3        small    unacc
# 70          high             high         4          big      acc
# 78          high              med         4          big      acc
# 81           low            vhigh     5more        small    unacc
# 82          high            vhigh     5more          med    unacc
# 109         high              med         4        small    unacc
# 116          med              med     5more        small      acc
# 152          low              low     5more        small      acc
# 153        vhigh             high         3          big    unacc
# 156         high              low         4          big      acc
# 171          med              med         4        small      acc
# 176        vhigh             high         2          med    unacc
# 188          low             high         2          big      acc
# 189        vhigh             high     5more        small    unacc
# 197         high             high     5more        small    unacc
# 199          low             high         4        small      acc
# 202          med            vhigh         4          med      acc
# 218        vhigh              med     5more          big      acc
# 222        vhigh            vhigh         3          med    unacc
# 223         high              med         3          big      acc
# 228         high             high         3          big      acc
# 234        vhigh            vhigh         4        small    unacc
# 245          low            vhigh         4          big      acc
# 256          low              low         2        small    unacc
# 273          med             high         3        small    unacc
# 305         high            vhigh         3          big    unacc
# 306         high             high         4        small    unacc
# 333         high              med         2          med    unacc
# 334          low             high     5more        small      acc
# 335          med            vhigh         2          med    unacc
# 336        vhigh            vhigh         2          med    unacc
# 342        vhigh              low         4          med      acc
# 345         high            vhigh         3          med    unacc
# 374          low             high         4          big      acc
# 384        vhigh              med         2        small    unacc
# 407        vhigh             high     5more          big    unacc
# 425          med             high     5more          med      acc
# 429        vhigh              low         4        small    unacc
# 444        vhigh            vhigh     5more          med    unacc
# 467        vhigh              low         3          big      acc
# 471          low              med     5more        small      acc
# 491          med             high     5more          big      acc
# 493         high              low         2          big      acc
# 496          low             high         3        small      acc
# ['acc' 'unacc'] [25 26]
# ...
#  ['high' 'low' 'med' 'vhigh'] [14 11  8 18]
# high
# low
# med
# vhigh
# entr_arr == >  [0.2745098  0.18233059 0.12725931 0.26971924]
# ans == >  0.14590369821244575 <class 'numpy.float64'>
# max_val == >  0.14590369821244575
# ['acc' 'unacc'] [25 26]
# ...
#  ['high' 'low' 'med' 'vhigh'] [17  9 11 14]
# high
# low
# med
# vhigh
# entr_arr == >  [0.33250085 0.16205221 0.18233059 0.16241998]
# ans == >  0.16041902013225517 <class 'numpy.float64'>
# max_val == >  0.16041902013225517
# ['acc' 'unacc'] [25 26]
# ...
#  ['2' '3' '4' '5more'] [10 12 15 14]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.14155453 0.23055735 0.24607081 0.2745098 ]
# ans == >  0.10703015424911377 <class 'numpy.float64'>
# ['acc' 'unacc'] [25 26]
# ...
#  ['big' 'med' 'small'] [18 12 21]
# big
# med
# small
# entr_arr == >  [0.26971924 0.21606961 0.37812181]
# ans == >  0.13581198791287152 <class 'numpy.float64'>
# gain_info--=> [0.1459037  0.16041902 0.10703015 0.13581199]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['vhigh' 'low' 'high' 'med']
#     buying_price num_doors size_luggage decision
# 8          vhigh     5more        small    unacc
# 20         vhigh         2          big    unacc
# 61           low         3        small    unacc
# 81           low     5more        small    unacc
# 82          high     5more          med    unacc
# 202          med         4          med      acc
# 222        vhigh         3          med    unacc
# 234        vhigh         4        small    unacc
# 245          low         4          big      acc
# ...
# 65               low         2        small      acc
# 71             vhigh         4        small    unacc
# 88               low         3        small      acc
# 283            vhigh         3          med    unacc
# 292            vhigh     5more          big      acc
# 312            vhigh         2        small    unacc
# 346             high     5more          big      acc
# 361            vhigh         3          big      acc
# 453              med         4        small      acc
# 462             high         3          med      acc
# ['acc' 'unacc'] [8 3]
# ...
#  ['high' 'low' 'med' 'vhigh'] [3 2 1 5]
# high
# low
# med
# vhigh
# entr_arr == >  [-0.         -0.         -0.          0.44134118]
# ans == >  0.40400975732485983 <class 'numpy.float64'>
# max_val == >  0.40400975732485983
# ['acc' 'unacc'] [8 3]
# ...
#  ['2' '3' '4' '5more'] [2 5 2 2]
# 2
# 3
# 4
# 5more
# entr_arr == >  [ 0.18181818  0.32814913  0.18181818 -0.        ]
# ans == >  0.15356543894636265 <class 'numpy.float64'>
# ['acc' 'unacc'] [8 3]
# ...
#  ['big' 'med' 'small'] [3 2 6]
# big
# med
# small
# entr_arr == >  [-0.          0.18181818  0.50088864]
# ans == >  0.1626441180472603 <class 'numpy.float64'>
# gain_info--=> [0.40400976 0.15356544 0.16264412]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['high' 'low' 'vhigh' 'med']
#     num_doors size_luggage decision
# 14          3        small      acc
# 346     5more          big      acc
# 462         3          med      acc
# ['acc'] [3]
# ...
#  ['3' '5more'] [2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [3]
# ...
#  ['big' 'med' 'small'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#    num_doors size_luggage decision
# 65         2        small      acc
# 88         3        small      acc
# ['acc'] [2]
# ...
#  ['2' '3'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [2]
# ...
#  ['small'] [2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 71          4        small    unacc
# 283         3          med    unacc
# 292     5more          big      acc
# 312         2        small    unacc
# 361         3          big      acc
# ['acc' 'unacc'] [2 3]
# ...
#  ['2' '3' '4' '5more'] [1 2 1 1]
# 2
# 3
# 4
# 5more
# entr_arr == >  [-0.   0.4 -0.  -0. ]
# ans == >  0.5709505944546686 <class 'numpy.float64'>
# max_val == >  0.5709505944546686
# ['acc' 'unacc'] [2 3]
# ...
#  ['big' 'med' 'small'] [2 1 2]
# big
# med
# small
# entr_arr == >  [-0. -0. -0.]
# ans == >  0.9709505944546686 <class 'numpy.float64'>
# max_val == >  0.9709505944546686
# gain_info--=> [0.57095059 0.97095059]
# gain_of_all ===>  size_luggage <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  size_luggage
#
# unique val  ['small' 'med' 'big']
#     num_doors decision
# 71          4    unacc
# 312         2    unacc
#     num_doors decision
# 283         3    unacc
#     num_doors decision
# 292     5more      acc
# 361         3      acc
#     num_doors size_luggage decision
# 453         4        small      acc
# ['acc'] [1]
# ...
#  ['4'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [1]
# ...
#  ['small'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     maintenance_cost num_doors size_luggage decision
# 19               low         2          big      acc
# 37              high         2        small    unacc
# 75               med         4        small    unacc
# 100              med         4          big      acc
# 108             high         3          big    unacc
# 169             high         4          med    unacc
# 240             high     5more          big    unacc
# 284            vhigh         2        small    unacc
# 329             high         2          big    unacc
# 338             high         4          big    unacc
# 398              low         2          med    unacc
# 412             high     5more          med    unacc
# 442              med         2          med    unacc
# ['acc' 'unacc'] [ 2 11]
# ...
#  ['high' 'low' 'med' 'vhigh'] [7 2 3 1]
# high
# low
# med
# vhigh
# entr_arr == >  [-0.          0.15384615  0.21191442 -0.        ]
# ans == >  0.25362161758926616 <class 'numpy.float64'>
# max_val == >  0.25362161758926616
# ['acc' 'unacc'] [ 2 11]
# ...
#  ['2' '3' '4' '5more'] [6 1 4 2]
# 2
# 3
# 4
# 5more
# entr_arr == >  [ 0.30001035 -0.          0.24962404 -0.        ]
# ans == >  0.06974780793055946 <class 'numpy.float64'>
# ['acc' 'unacc'] [ 2 11]
# ...
#  ['big' 'med' 'small'] [6 4 3]
# big
# med
# small
# entr_arr == >  [ 0.42382885 -0.         -0.        ]
# ans == >  0.19555334819207626 <class 'numpy.float64'>
# gain_info--=> [0.25362162 0.06974781 0.19555335]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['low' 'high' 'med' 'vhigh']
#     num_doors size_luggage decision
# 19          2          big      acc
# 398         2          med    unacc
# ['acc' 'unacc'] [1 1]
# ...
#  ['2'] [2]
# 2
# entr_arr == >  [1.]
# ans == >  0.0 <class 'numpy.float64'>
# ['acc' 'unacc'] [1 1]
# ...
#  ['big' 'med'] [1 1]
# big
# med
# entr_arr == >  [-0. -0.]
# ans == >  1.0 <class 'numpy.float64'>
# max_val == >  1.0
# gain_info--=> [0. 1.]
# gain_of_all ===>  size_luggage <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  size_luggage
#
# unique val  ['big' 'med']
#    num_doors decision
# 19         2      acc
#     num_doors decision
# 398         2    unacc
#     num_doors size_luggage decision
# 37          2        small    unacc
# 108         3          big    unacc
# 169         4          med    unacc
# 240     5more          big    unacc
# 329         2          big    unacc
# 338         4          big    unacc
# 412     5more          med    unacc
# ['unacc'] [7]
# ...
#  ['2' '3' '4' '5more'] [2 1 2 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [7]
# ...
#  ['big' 'med' 'small'] [4 2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 75          4        small    unacc
# 100         4          big      acc
# 442         2          med    unacc
# ['acc' 'unacc'] [1 2]
# ...
#  ['2' '4'] [1 2]
# 2
# 4
# entr_arr == >  [-0.          0.66666667]
# ans == >  0.2516291673878229 <class 'numpy.float64'>
# max_val == >  0.2516291673878229
# ['acc' 'unacc'] [1 2]
# ...
#  ['big' 'med' 'small'] [1 1 1]
# big
# med
# small
# entr_arr == >  [-0. -0. -0.]
# ans == >  0.9182958340544896 <class 'numpy.float64'>
# max_val == >  0.9182958340544896
# gain_info--=> [0.25162917 0.91829583]
# gain_of_all ===>  size_luggage <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  size_luggage
#
# unique val  ['small' 'big' 'med']
#    num_doors decision
# 75         4    unacc
#     num_doors decision
# 100         4      acc
#     num_doors decision
# 442         2    unacc
#     num_doors size_luggage decision
# 284         2        small    unacc
# ['unacc'] [1]
# ...
#  ['2'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [1]
# ...
#  ['small'] [1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     maintenance_cost num_doors size_luggage decision
# 24              high         2          big      acc
# 62              high         4        small    unacc
# 83               med         2        small      acc
# 98             vhigh         4          med      acc
# 105              med         2          med      acc
# 128              low         3        small      acc
# 253            vhigh     5more        small    unacc
# 287            vhigh         3          med    unacc
# 317            vhigh     5more          med      acc
# 332            vhigh         3        small    unacc
# 341              med     5more          med      acc
# 348             high     5more          big      acc
# 351              med         3        small      acc
# 385             high         2        small    unacc
# 386              med         4          med      acc
# 486              low     5more        small      acc
# ['acc' 'unacc'] [11  5]
# ...
#  ['high' 'low' 'med' 'vhigh'] [4 2 5 5]
# high
# low
# med
# vhigh
# entr_arr == >  [ 0.25       -0.         -0.          0.30342206]
# ans == >  0.3426161717674735 <class 'numpy.float64'>
# max_val == >  0.3426161717674735
# ['acc' 'unacc'] [11  5]
# ...
#  ['2' '3' '4' '5more'] [4 4 3 5]
# 2
# 3
# 4
# 5more
# entr_arr == >  [0.20281953 0.25       0.17218047 0.22560253]
# ans == >  0.04543570288225662 <class 'numpy.float64'>
# ['acc' 'unacc'] [11  5]
# ...
#  ['big' 'med' 'small'] [2 6 8]
# big
# med
# small
# entr_arr == >  [-0.          0.24375841  0.5       ]
# ans == >  0.15227982441642463 <class 'numpy.float64'>
# gain_info--=> [0.34261617 0.0454357  0.15227982]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['high' 'med' 'vhigh' 'low']
#     num_doors size_luggage decision
# 24          2          big      acc
# 62          4        small    unacc
# 348     5more          big      acc
# 385         2        small    unacc
# ['acc' 'unacc'] [2 2]
# ...
#  ['2' '4' '5more'] [2 1 1]
# 2
# 4
# 5more
# entr_arr == >  [ 0.5 -0.  -0. ]
# ans == >  0.5 <class 'numpy.float64'>
# max_val == >  0.5
# ['acc' 'unacc'] [2 2]
# ...
#  ['big' 'small'] [2 2]
# big
# small
# entr_arr == >  [-0. -0.]
# ans == >  1.0 <class 'numpy.float64'>
# max_val == >  1.0
# gain_info--=> [0.5 1. ]
# gain_of_all ===>  size_luggage <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  size_luggage
#
# unique val  ['big' 'small']
#     num_doors decision
# 24          2      acc
# 348     5more      acc
#     num_doors decision
# 62          4    unacc
# 385         2    unacc
#     num_doors size_luggage decision
# 83          2        small      acc
# 105         2          med      acc
# 341     5more          med      acc
# 351         3        small      acc
# 386         4          med      acc
# ['acc'] [5]
# ...
#  ['2' '3' '4' '5more'] [2 1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [5]
# ...
#  ['med' 'small'] [3 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 98          4          med      acc
# 253     5more        small    unacc
# 287         3          med    unacc
# 317     5more          med      acc
# 332         3        small    unacc
# ['acc' 'unacc'] [2 3]
# ...
#  ['3' '4' '5more'] [2 1 2]
# 3
# 4
# 5more
# entr_arr == >  [-0.  -0.   0.4]
# ans == >  0.5709505944546686 <class 'numpy.float64'>
# max_val == >  0.5709505944546686
# ['acc' 'unacc'] [2 3]
# ...
#  ['med' 'small'] [3 2]
# med
# small
# entr_arr == >  [ 0.5509775 -0.       ]
# ans == >  0.4199730940219749 <class 'numpy.float64'>
# gain_info--=> [0.57095059 0.41997309]
# gain_of_all ===>  num_doors <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  num_doors
#
# unique val  ['4' '5more' '3']
#    size_luggage decision
# 98          med      acc
#     size_luggage decision
# 253        small    unacc
# 317          med      acc
#     size_luggage decision
# 287          med    unacc
# 332        small    unacc
#     num_doors size_luggage decision
# 128         3        small      acc
# 486     5more        small      acc
# ['acc'] [2]
# ...
#  ['3' '5more'] [1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['acc'] [2]
# ...
#  ['small'] [2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     maintenance_cost num_doors size_luggage decision
# 69               low         4        small    unacc
# 163            vhigh         2          big    unacc
# 181              med     5more          big      acc
# 183              med         4          med      acc
# 205            vhigh         2          med    unacc
# 206             high         4        small    unacc
# 235             high     5more        small    unacc
# 246            vhigh         4          med    unacc
# 249              med     5more          med      acc
# 392              med     5more        small    unacc
# 397              med         4        small    unacc
# 419              low     5more          med      acc
# 448              med         2          big      acc
# 475             high         3          med    unacc
# ['acc' 'unacc'] [5 9]
# ...
#  ['high' 'low' 'med' 'vhigh'] [3 2 6 3]
# high
# low
# med
# vhigh
# entr_arr == >  [-0.          0.14285714  0.39355536 -0.        ]
# ans == >  0.4038734583615642 <class 'numpy.float64'>
# max_val == >  0.4038734583615642
# ['acc' 'unacc'] [5 9]
# ...
#  ['2' '3' '4' '5more'] [3 1 5 5]
# 2
# 3
# 4
# 5more
# entr_arr == >  [ 0.19677768 -0.          0.25783146  0.34676807]
# ans == >  0.13890874803680098 <class 'numpy.float64'>
# ['acc' 'unacc'] [5 9]
# ...
#  ['big' 'med' 'small'] [3 6 5]
# big
# med
# small
# entr_arr == >  [ 0.19677768  0.42857143 -0.        ]
# ans == >  0.31493685137324057 <class 'numpy.float64'>
# gain_info--=> [0.40387346 0.13890875 0.31493685]
# gain_of_all ===>  maintenance_cost <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  maintenance_cost
#
# unique val  ['low' 'vhigh' 'med' 'high']
#     num_doors size_luggage decision
# 69          4        small    unacc
# 419     5more          med      acc
# ['acc' 'unacc'] [1 1]
# ...
#  ['4' '5more'] [1 1]
# 4
# 5more
# entr_arr == >  [-0. -0.]
# ans == >  1.0 <class 'numpy.float64'>
# max_val == >  1.0
# ['acc' 'unacc'] [1 1]
# ...
#  ['med' 'small'] [1 1]
# med
# small
# entr_arr == >  [-0. -0.]
# ans == >  1.0 <class 'numpy.float64'>
# gain_info--=> [1. 1.]
# gain_of_all ===>  num_doors <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  num_doors
#
# unique val  ['4' '5more']
#    size_luggage decision
# 69        small    unacc
#     size_luggage decision
# 419          med      acc
#     num_doors size_luggage decision
# 163         2          big    unacc
# 205         2          med    unacc
# 246         4          med    unacc
# ['unacc'] [3]
# ...
#  ['2' '4'] [2 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [3]
# ...
#  ['big' 'med'] [1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>
#     num_doors size_luggage decision
# 181     5more          big      acc
# 183         4          med      acc
# 249     5more          med      acc
# 392     5more        small    unacc
# 397         4        small    unacc
# 448         2          big      acc
# ['acc' 'unacc'] [4 2]
# ...
#  ['2' '4' '5more'] [1 2 3]
# 2
# 4
# 5more
# entr_arr == >  [-0.          0.33333333  0.45914792]
# ans == >  0.12581458369391152 <class 'numpy.float64'>
# max_val == >  0.12581458369391152
# ['acc' 'unacc'] [4 2]
# ...
#  ['big' 'med' 'small'] [2 2 2]
# big
# med
# small
# entr_arr == >  [-0. -0. -0.]
# ans == >  0.9182958340544896 <class 'numpy.float64'>
# max_val == >  0.9182958340544896
# gain_info--=> [0.12581458 0.91829583]
# gain_of_all ===>  size_luggage <class 'str'>
#  ------------------------------------
#
#
# in buit tree function==> max_val_attriubutr =  size_luggage
#
# unique val  ['big' 'med' 'small']
#     num_doors decision
# 181     5more      acc
# 448         2      acc
#     num_doors decision
# 183         4      acc
# 249     5more      acc
#     num_doors decision
# 392     5more    unacc
# 397         4    unacc
#     num_doors size_luggage decision
# 206         4        small    unacc
# 235     5more        small    unacc
# 475         3          med    unacc
# ['unacc'] [3]
# ...
#  ['3' '4' '5more'] [1 1 1]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# ['unacc'] [3]
# ...
#  ['med' 'small'] [1 2]
# entr_arr == >  [0]
# ans == >  -0.0 <class 'numpy.float64'>
# gain_info--=> [-0. -0.]
# gain_of_all ===>  null <class 'str'>

# %%
car_tree.print_tree()
# Out:
#  start=start
# ├──  safety=high
# │   ├──  num_persons=more
# │   │   ├──  maintenance_cost=vhigh
# │   │   │   ├──  buying_price=med
# │   │   │   │   ├──  num_doors=2
# │   │   │   │   ├──  num_doors=5more
# │   │   │   │   ├──  num_doors=3
# │   │   │   │   └──  num_doors=4
# │   │   │   ├──  buying_price=high
# │   │   │   │   └──  class=unacc
# │   │   │   ├──  buying_price=low
# │   │   │   │   └──  class=acc
# │   │   │   └──  buying_price=vhigh
# │   │   │       └──  class=unacc
# │   │   ├──  maintenance_cost=low
# │   │   │   ├──  num_doors=4
# │   │   │   │   └──  class=acc
# │   │   │   ├──  num_doors=3
# │   │   │   │   └──  class=acc
# │   │   │   ├──  num_doors=5more
# │   │   │   │   └──  class=acc
# │   │   │   └──  num_doors=2
# │   │   │       ├──  size_luggage=med
# │   │   │       └──  size_luggage=small
# │   │   ├──  maintenance_cost=med
# │   │   │   ├──  buying_price=med
# │   │   │   │   └──  class=acc
# │   │   │   ├──  buying_price=vhigh
# │   │   │   │   └──  class=acc
# │   │   │   ├──  buying_price=high
# │   │   │   │   └──  class=acc
# │   │   │   └──  buying_price=low
# │   │   │       └──  class=unacc
# │   │   └──  maintenance_cost=high
# │   │       ├──  buying_price=high
# │   │       │   └──  class=acc
# │   │       ├──  buying_price=med
# │   │       │   └──  class=acc
# │   │       └──  buying_price=vhigh
# │   │           └──  class=unacc
# │   ├──  num_persons=4
# │   │   ├──  maintenance_cost=med
# │   │   │   └──  class=acc
# │   │   ├──  maintenance_cost=vhigh
# │   │   │   ├──  buying_price=low
# │   │   │   │   └──  class=acc
# │   │   │   ├──  buying_price=vhigh
# │   │   │   │   └──  class=unacc
# │   │   │   ├──  buying_price=high
# │   │   │   │   └──  class=unacc
# │   │   │   └──  buying_price=med
# │   │   │       └──  class=acc
# │   │   ├──  maintenance_cost=low
# │   │   │   └──  class=acc
# │   │   └──  maintenance_cost=high
# │   │       ├──  buying_price=vhigh
# │   │       │   └──  class=unacc
# │   │       ├──  buying_price=high
# │   │       │   └──  class=acc
# │   │       ├──  buying_price=med
# │   │       │   └──  class=acc
# │   │       └──  buying_price=low
# │   │           └──  class=acc
# │   └──  num_persons=2
# │       └──  class=unacc
# ├──  safety=low
# │   └──  class=unacc
# └──  safety=med
#     ├──  num_persons=more
#     │   ├──  maintenance_cost=vhigh
#     │   │   ├──  num_doors=5more
#     │   │   │   └──  class=unacc
#     │   │   ├──  num_doors=2
#     │   │   │   └──  class=unacc
#     │   │   ├──  num_doors=3
#     │   │   │   └──  class=unacc
#     │   │   └──  num_doors=4
#     │   │       ├──  buying_price=med
#     │   │       ├──  buying_price=vhigh
#     │   │       └──  buying_price=low
#     │   ├──  maintenance_cost=low
#     │   │   ├──  size_luggage=big
#     │   │   │   └──  class=acc
#     │   │   ├──  size_luggage=small
#     │   │   │   ├──  num_doors=2
#     │   │   │   ├──  num_doors=5more
#     │   │   │   └──  num_doors=4
#     │   │   └──  size_luggage=med
#     │   │       └──  class=acc
#     │   ├──  maintenance_cost=high
#     │   │   ├──  buying_price=vhigh
#     │   │   │   └──  class=unacc
#     │   │   ├──  buying_price=high
#     │   │   │   ├──  size_luggage=big
#     │   │   │   └──  size_luggage=small
#     │   │   ├──  buying_price=low
#     │   │   │   └──  class=acc
#     │   │   └──  buying_price=med
#     │   │       ├──  num_doors=3
#     │   │       └──  num_doors=5more
#     │   └──  maintenance_cost=med
#     │       ├──  num_doors=4
#     │       │   ├──  buying_price=med
#     │       │   ├──  buying_price=vhigh
#     │       │   └──  buying_price=high
#     │       ├──  num_doors=5more
#     │       │   └──  class=acc
#     │       ├──  num_doors=3
#     │       │   └──  class=acc
#     │       └──  num_doors=2
#     │           └──  class=unacc
#     ├──  num_persons=2
#     │   └──  class=unacc
#     └──  num_persons=4
#         ├──  buying_price=low
#         │   ├──  maintenance_cost=high
#         │   │   └──  class=acc
#         │   ├──  maintenance_cost=low
#         │   │   └──  class=acc
#         │   ├──  maintenance_cost=vhigh
#         │   │   ├──  size_luggage=small
#         │   │   ├──  size_luggage=med
#         │   │   └──  size_luggage=big
#         │   └──  maintenance_cost=med
#         │       └──  class=acc
#         ├──  buying_price=vhigh
#         │   ├──  maintenance_cost=low
#         │   │   ├──  size_luggage=big
#         │   │   └──  size_luggage=med
#         │   ├──  maintenance_cost=high
#         │   │   └──  class=unacc
#         │   ├──  maintenance_cost=med
#         │   │   ├──  size_luggage=small
#         │   │   ├──  size_luggage=big
#         │   │   └──  size_luggage=med
#         │   └──  maintenance_cost=vhigh
#         │       └──  class=unacc
#         ├──  buying_price=med
#         │   ├──  maintenance_cost=high
#         │   │   ├──  size_luggage=big
#         │   │   └──  size_luggage=small
#         │   ├──  maintenance_cost=med
#         │   │   └──  class=acc
#         │   ├──  maintenance_cost=vhigh
#         │   │   ├──  num_doors=4
#         │   │   ├──  num_doors=5more
#         │   │   └──  num_doors=3
#         │   └──  maintenance_cost=low
#         │       └──  class=acc
#         └──  buying_price=high
#             ├──  maintenance_cost=low
#             │   ├──  num_doors=4
#             │   └──  num_doors=5more
#             ├──  maintenance_cost=vhigh
#             │   └──  class=unacc
#             ├──  maintenance_cost=med
#             │   ├──  size_luggage=big
#             │   ├──  size_luggage=med
#             │   └──  size_luggage=small
#             └──  maintenance_cost=high
#                 └──  class=unacc
