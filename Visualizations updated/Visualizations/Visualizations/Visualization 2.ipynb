# %% [markdown]
# # Subplots

# %%
#%matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

#plt.subplot?

# %%
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 2, 1)

linear_data = np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data, '-o')

plt.subplot(1, 2, 2)

exponential_data = np.power(np.array([1,2,3,4,5,6,7,8]),2)
plt.plot(exponential_data, '-o')

# %%
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 2, 1)

linear_data = np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data, '-o',label='linear')
plt.xlabel("Number")
plt.ylabel("Value")
plt.title("Linear Graph")
plt.legend()


plt.subplot(1, 2, 2)

exponential_data = np.power(np.array([1,2,3,4,5,6,7,8]),2)
plt.plot(exponential_data, '-g>',label='exponential')
plt.xlabel("Number")
plt.ylabel("Value")
plt.title("Exponential Graph")
plt.legend()

# %%
plt.figure(figsize=(20, 15))
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 3, 1)

linear_data = np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data, '-o',label='linear')
plt.xlabel("Number")
plt.ylabel("Value")
plt.title("Linear Graph")
plt.legend()


plt.subplot(1, 3, 2)

exponential_data = np.power(np.array([1,2,3,4,5,6,7,8]),2)
plt.plot(exponential_data, '-g>',label='exponential')
plt.xlabel("Number")
plt.ylabel("Value")
plt.title("Exponential Graph")
plt.legend(loc='best')


plt.subplot(1, 3, 3)

log_data = np.log(np.array([1,2,3,4,5,6,7,8]))
plt.plot(log_data, '-r*',label='log')
plt.xlabel("Number")
plt.ylabel("Value")
plt.title("Log Graph")
plt.legend()

# %%
# create a 3x3 grid of subplots
#plt.subplots(3, 3, sharex=True, sharey=True)
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(20, 15))
# plot the linear_data on the 5th subplot axes 
ax5.plot(linear_data, '-.')
#ax1.plot(log_data, '-o')
#ax5.plot(exponential_data, '-o')

# %% [markdown]
# # Histograms

# %%
# create 2x2 grid of axis subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

# draw n = 10, 100, 1000, and 10000 samples from the normal distribution and plot corresponding histograms
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))

# %%
# repeat with number of bins set to 100
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1, size=sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title('n={}'.format(sample_size))

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)

# %% [markdown]
# # Box Plots

# %% [markdown]
# <img src="images/box_plots.png">

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.004206      0.498978      2.000435
# std        0.995507      0.287894      1.407903
# min       -3.698158      0.000192      0.006087
# 25%       -0.683979      0.247602      0.967116
# 50%        0.002627      0.500063      1.708329
# 75%        0.666712      0.748617      2.657656
# max        3.589334      0.999900     15.703383

# %%
plt.figure()
# create a boxplot of the normal data, assign the output to a variable to supress output
_ = plt.boxplot(df['normal'])

# %%
# clear the current figure
plt.clf()
# plot boxplots for all three of df's columns
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ])

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins=1000)

# %%
plt.figure()
_ = plt.hist(df['normal'], bins=100)

# %%
plt.figure()
_ = plt.hist(df['random'], bins=100)

# %% [markdown]
# # Heatmaps

# %%
plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.normal(loc=0.0, scale=1.0, size=10000)

#X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=10)

# %%
plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=125)

# %%
plt.figure()
_ = plt.hist2d(X, Y, bins=100)
plt.colorbar()
