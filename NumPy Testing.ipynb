# %%
import pandas as pd
import numpy as np
import matplotlib_inline as plt
import plotly.graph_objects as go

# %% [markdown]
# # why we use pca
# pca reduce the dimentionality of the data
# we cant redice the dimentions without any intuation

# %%
merg = pd.read_excel('merged_all.xlsx')

# %%
merg.head(10)
# Out:
#    Unnamed: 0  AccountSeq  CampaignSeq  CloseDate  ProductSeq  \
# 0           0        1000          NaN 2019-09-03           8
# 1           1        1000          NaN 2019-10-26           8
# 2           2        1000          NaN 2019-11-20           8
# 3           3        1000          NaN 2019-11-21           8
# 4           4        1000          NaN 2019-12-19           8
# 5           5        1000          NaN 2019-12-19           8
# 6           6        1000          NaN 2019-12-22           8
# 7           7        1000          NaN 2020-01-21           8
# 8           8        1000          NaN 2020-04-04           8
# 9           9        1000          NaN 2020-05-01           8
#
#   Purchase Process Rating Sales Stage Status  SystemUserSeq  ...  \
# 0        Committee   Cold   1-Qualify   Lost             11  ...
# 1          Unknown   Cold   1-Qualify   Lost             11  ...
# 2       Individual   Cold   1-Qualify   Lost             11  ...
# ...

# %%
merg.describe()
# Out:
#          Unnamed: 0    AccountSeq   CampaignSeq    ProductSeq  SystemUserSeq  \
# count  19990.000000  19990.000000  13263.000000  19990.000000   19990.000000
# mean    9994.500000   1084.725063   7005.266682      5.859080      10.132866
# std     5770.760276     75.287413      4.135192      2.279245       5.919850
# min        0.000000   1000.000000   7000.000000      1.000000       1.000000
# 25%     4997.250000   1015.000000   7000.000000      4.000000       5.000000
# 50%     9994.500000   1060.000000   7006.000000      6.000000      10.000000
# 75%    14991.750000   1148.000000   7009.000000      8.000000      14.000000
# max    19989.000000   1299.000000   7011.000000      9.000000      20.000000
#
#               Value      Discount  OpportunitySeq   Probability  \
# count  19990.000000  19990.000000    19990.000000  19990.000000
# mean    3864.543072      0.107901    20009.504752      0.309505
# std     1796.540440      0.030629     5781.349152      0.248362
# ...

# %%
merg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19990 entries, 0 to 19989
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 19990 non-null  int64
#  1   AccountSeq                 19990 non-null  int64
#  2   CampaignSeq                13263 non-null  float64
#  3   CloseDate                  19990 non-null  datetime64[ns]
#  4   ProductSeq                 19990 non-null  int64
#  5   Purchase Process           19990 non-null  object
#  6   Rating                     19990 non-null  object
#  7   Sales Stage                19990 non-null  object
#  8   Status                     19990 non-null  object
#  9   SystemUserSeq              19990 non-null  int64
#  10  Value                      19990 non-null  int64
#  11  Decision Maker Identified  19990 non-null  bool
#  12  Opportunity Created On     19990 non-null  datetime64[ns]
# ...
